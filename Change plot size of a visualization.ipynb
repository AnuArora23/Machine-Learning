# %% [markdown]
# ## Topics Discussed :
# 1. Reading Dataset
# 2. Dropping columns
# 3. Plotting visualization
# 4. resize figure size

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Reading Dataset

# %%
df=pd.read_csv('epilepsy.csv')
df
# Out:
#        Unnamed: 0          AF3          AF4           F3           F4  \
# 0               1  4426.153846  3994.871795  4408.205128  3847.692308
# 1               2  4420.512821  3986.666667  4394.358974  3836.923077
# 2               3  4413.846154  3986.153846  4386.666667  3831.794872
# 3               4  4407.692308  3984.615385  4384.102564  3832.820513
# 4               5  4407.179487  3978.974359  4382.564103  3832.307692
# ...           ...          ...          ...          ...          ...
# 38523       38524  4049.230769  3826.666667  4003.589744  3550.256410
# 38524       38525  4056.410256  3832.307692  4002.051282  3554.358974
# 38525       38526  4060.512821  3835.897436  4006.666667  3561.538462
# 38526       38527  4052.820513  3827.179487  4006.666667  3559.487179
# 38527       38528  4047.692308  3823.589744  4003.589744  3552.820513
#
#                 F7           F8          FC5          FC6           O1  ...  \
# ...

# %% [markdown]
# ## To see all the column headers

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'AF3', 'AF4', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'O1',
#        'O2', 'P7', 'P8', 'T7', 'T8', 'COUNTER', 'INTERPOLATED', 'GYROX',
#        'GYROY', 'RAW_CQ', 'CQ_CMS', 'CQ_F7', 'CQ_T7', 'CQ_O2', 'CQ_FC6',
#        'CQ_AF4', 'CQ_F3', 'CQ_P7', 'CQ_P8', 'CQ_F4', 'CQ_AF3', 'CQ_FC5',
#        'CQ_O1', 'CQ_T8', 'CQ_F8', 'CQ_DRL'],
#       dtype='object')

# %% [markdown]
# ## Dropping 1 Column from dataset

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)
print(df.head())
# Out:
#            AF3          AF4           F3           F4           F7  \
# 0  4426.153846  3994.871795  4408.205128  3847.692308  4690.256410
# 1  4420.512821  3986.666667  4394.358974  3836.923077  4678.461538
# 2  4413.846154  3986.153846  4386.666667  3831.794872  4654.871795
# 3  4407.692308  3984.615385  4384.102564  3832.820513  4644.615385
# 4  4407.179487  3978.974359  4382.564103  3832.307692  4647.692308
#
#             F8          FC5          FC6           O1           O2  ...  \
# 0  3895.897436  4702.051282  3914.871795  4049.743590  4297.948718  ...
# 1  3886.666667  4696.410256  3910.769231  4054.358974  4295.897436  ...
# 2  3881.025641  4690.769231  3908.205128  4066.666667  4301.025641  ...
# 3  3883.076923  4686.153846  3910.256410  4063.076923  4298.974359  ...
# 4  3878.974359  4685.641026  3903.076923  4057.948718  4295.384615  ...
#
#    CQ_F3  CQ_P7  CQ_P8  CQ_F4  CQ_AF3  CQ_FC5  CQ_O1  CQ_T8  CQ_F8  CQ_DRL
# ...

# %% [markdown]
# ## Dropping multiple Columns from dataset

# %%
df.drop(['F7','F8','FC5','FC6'],axis=1,inplace=True)
print(df.head())
# Out:
#            AF3          AF4           F3           F4           O1  \
# 0  4426.153846  3994.871795  4408.205128  3847.692308  4049.743590
# 1  4420.512821  3986.666667  4394.358974  3836.923077  4054.358974
# 2  4413.846154  3986.153846  4386.666667  3831.794872  4066.666667
# 3  4407.692308  3984.615385  4384.102564  3832.820513  4063.076923
# 4  4407.179487  3978.974359  4382.564103  3832.307692  4057.948718
#
#             O2           P7           P8           T7           T8  ...  \
# 0  4297.948718  4186.153846  4132.820513  4106.666667  4076.410256  ...
# 1  4295.897436  4187.179487  4126.666667  4105.641026  4065.128205  ...
# 2  4301.025641  4188.205128  4123.076923  4103.076923  4063.589744  ...
# 3  4298.974359  4184.615385  4127.179487  4095.384615  4071.282051  ...
# 4  4295.384615  4182.564103  4128.205128  4090.769231  4064.102564  ...
#
#    CQ_F3  CQ_P7  CQ_P8  CQ_F4  CQ_AF3  CQ_FC5  CQ_O1  CQ_T8  CQ_F8  CQ_DRL
# ...

# %%
df.drop(['O2', 'P7','P8', 'T7', 'T8', 'COUNTER', 'INTERPOLATED', 'GYROX', 'GYROY', 'RAW_CQ',
       'CQ_CMS', 'CQ_F7', 'CQ_T7', 'CQ_O2', 'CQ_FC6', 'CQ_AF4', 'CQ_F3',
       'CQ_P7', 'CQ_P8', 'CQ_F4', 'CQ_AF3', 'CQ_FC5', 'CQ_O1', 'CQ_T8',
       'CQ_F8', 'CQ_DRL'],axis=1,inplace=True)

# %% [markdown]
# ## Plotting histogram

# %%
#plt.figure(figsize=(111,100))

df.hist(figsize=(10,8))
plt.show()
